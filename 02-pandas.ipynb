# %%
import pandas as pd

dataset = pd.read_csv("data/dataset.csv")
# pd.read_csv("data/dataset.csv", index_col="id")

# dataset.head() # muestra las primeas 5 

# dataset.describe()

dataset
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# ## Limpieza de datos

# %%
# cuando hay datos vacios podemos eliminar esos datos
dataset_filtrado = dataset.dropna() # elimina las filas completas < -- > 
dataset_filtrado

# cambiar el valor de NAN
dataset_filtrado = dataset.fillna(0) # cambiar valor NAN por 0

# limpiar multiples datos
dataset_filtrado = dataset.fillna({'retweets': 0, 'mentions': 0})

# %% [markdown]
# ## Filtrado de columnas

# %%
# mostrar sola una columna full_text / los datos se repiten
dataset_filtrado['full_text']

# dataset_filtrado['country']

# mostrar 2 columnas
dataset_filtrado[['full_text', 'country']]
# Out:
#                                             full_text  country
# 0   Flying home to run down from the power to comi...  ECUADOR
# 1                 Today we commemorate and MNML Case.   BRASIL
# 2        Today we have reached US$6.55 Billion TT$44…   MEXICO
# 3   Faking It by Joel Atwell. Written by Other cou...  ECUADOR
# 4                                     Welcome back! 🙌   MEXICO
# 5   Contest: Win a fan of his ass. #thatisall Thanks!   BRASIL
# 6                                  80's & friends! ✈️  ECUADOR
# 7   Thank you guess how did I feel somewhat offend...   MEXICO
# 8         OnePlus 8 international giveaway classifies   MEXICO
# 9                 Here it is.. Retweet this desperate   BRASIL
# 10  Great to advertise during the year I tweeted a...   BRASIL
# 11  Its been in love with the game with the origin...   BRASIL
# 12                           Programming is the best!  ECUADOR
# 13                             I cannot believe this!  ECUADOR
# ...

# %% [markdown]
# ## Filtrado por filas

# %%
# mostrar las 10 primeras filas
dataset.iloc[0:10]

# mostrar de 10 - 20 filas
dataset.iloc[10:20]

# mostrar de 10 - 20 filas con filtrado de texto y country
dataset.loc[10: 20, ['full_text', 'country']]
# Out:
#                                             full_text  country
# 10  Great to advertise during the year I tweeted a...   BRASIL
# 11  Its been in love with the game with the origin...   BRASIL
# 12                           Programming is the best!  ECUADOR
# 13                             I cannot believe this!  ECUADOR
# 14                             Buy this product NOW!!   MEXICO
# 15  I have one is best color gradients: Just relea...   MEXICO
# 16                                              PIC!!   BRASIL
# 17                             hmmm feeling bad today   MEXICO
# 18                          not feeling god right now  ECUADOR
# 19                        Programming is a hot topic!   BRASIL
# 20                            Programming? i love it!  ECUADOR

# %% [markdown]
# ## Filtrado por condicion

# %%
# mostrar los country de ecuador
# dataset_filtrado[dataset_filtrado['country'] == "ECUADOR"]

# mostrar los followers mayor a 300
# dataset_filtrado[dataset_filtrado['followers'] > 300]

# mostrar los followers menor a 300
dataset_filtrado[dataset_filtrado['followers'] < 300]

# 2 condiciones mostrar tweets favoritos arriba de 400 y con followers mayor a 900
dataset_filtrado[(dataset_filtrado['favorites'] > 400) & (dataset_filtrado['followers'] > 900)]

# mostra datos con reetweets mayor o igual a 123 y country mexico
dataset_filtrado[(dataset_filtrado['retweets'] >= 123) & (dataset_filtrado['country'] == "MEXICO")]

# filtrar por texto Programming
dataset_filtrado[dataset_filtrado['full_text'].str.contains('Programming')]
# Out:
#         id                    full_text  favorites  retweets  mentions  \
# 12  183733     Programming is the best!      467.0      69.0      10.0
# 19  183740  Programming is a hot topic!      133.0     145.0      15.0
# 20  183741      Programming? i love it!       92.0     146.0       1.0
#
#     country           user  followers  followees
# 12  ECUADOR  leonardokuffo      389.0        258
# 19   BRASIL     lucasperes       82.0        351
# 20  ECUADOR   galocastillo      332.0        378

# %% [markdown]
# ## Crear nuevos datos

# %%
dataset_filtrado

def followersAndFollowees(row):
    return row['followers'] + row['followees']

# Aplica la función a cada fila del DataFrame
dataset_filtrado['followersAndFollowees'] = dataset_filtrado.apply(followersAndFollowees, axis=1)

dataset_filtrado
# Out:
#         id                                          full_text  favorites  \
# 0   183721  Flying home to run down from the power to comi...       23.0
# 1   183722                Today we commemorate and MNML Case.      500.0
# 2   183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 3   183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 4   183725                                    Welcome back! 🙌      113.0
# 5   183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 6   183727                                 80's & friends! ✈️      158.0
# 7   183728  Thank you guess how did I feel somewhat offend...        NaN
# 8   183729        OnePlus 8 international giveaway classifies      198.0
# 9   183730                Here it is.. Retweet this desperate      272.0
# 10  183731  Great to advertise during the year I tweeted a...       43.0
# 11  183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# ## Graficos de datos

# %%
import matplotlib.pyplot as plt

dataset_filtrado.plot()
# Out:
# <Axes: >

# %%
# eje x e y
dataset_filtrado.plot(kind='scatter', x='favorites', y='retweets')
# Out:
# <Axes: xlabel='favorites', ylabel='retweets'>
